# %% [markdown]
# # Yacine Mahdid May 19 2020
# The goal here is to do the same thing we did with permutation entropy and to have a bootstrap confidence interval code that we can reuse across analysis.
#
# - [X] Take the code from an old project and refactor it into a easy to use function
# - [X] Use the bootstrap confidence interval code on the dataset to get a range
# - [X] Refactor the code into the utility library

# %%
from math import floor

# Data manipulation
import numpy as np
import pandas as pd

from sklearn.utils import resample

# Library import
from ml_tools.classification import classify_loso
from ml_tools.pre_processing import pre_process

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC

def bootstrap_interval(X, y, group, clf, num_resample=1000, p_value=0.05):
    """Create a confidence interval for the classifier with the given p value
        
        Args:
            X (numpy matrix): The feature matrix with which we want to train on classifier on
            y (numpy vector): The label for each row of data point
            group (numpy vector): The group id for each row in the data (correspond to the participant ids) 
            clf (sklearn classifier): The classifier that we which to train and validate with bootstrap interval
            num_resample (int): The number of resample we want to do to create our distribution
            p_value (float): The p values for the upper and lower bound
        
        Returns:
            acc_distribution (float vector): the distribution of all the accuracies
            acc_interval (float vector): a lower and upper interval on the accuracies corresponding to the p value
    """
    

    acc_distribution = []
    for id in range(num_resample):
        print("Bootstrap sample #" + str(id))
        
        # Get the sampled with replacement dataset
        sample_X, sample_y, sample_group = resample(X, y, group)

        # Classify and get the results
        accuracies = classify_loso(sample_X, sample_y, sample_group, clf)
        acc_distribution.append(np.mean(accuracies))
    
    # Sort the results
    acc_distribution.sort()

    # Set the confidence interval at the right index
    lower_index = floor(num_resample*(p_value/2))
    upper_index = floor(num_resample*(1 - (p_value/2)))
    acc_interval = acc_distribution[lower_index], acc_distribution[upper_index]

    return acc_distribution, acc_interval

# Setup the experiment to test the above function
input_filename = '/home/yacine/Documents/BIAPT/data_window_10.csv'

pipe = Pipeline([
    ('imputer', SimpleImputer(missing_values=np.nan, strategy='mean')),
    ('scaler', StandardScaler()),
    ('SVM', SVC())])

X,y,group,df = pre_process(input_filename, "MSK")
acc_distribution, acc_interval = bootstrap_interval(X, y, group, pipe, num_resample=10, p_value=0.05)
# Out:
# Bootstrap sample #0
# Bootstrap sample #1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b8e63a1e0a31> in <module>
#      63
#      64 X,y,group,df = pre_process(input_filename, "MSK")
# ---> 65 acc_distribution, acc_interval = bootstrap_interval(X, y, group, pipe, num_resample=100, p_value=0.05)
#
# <ipython-input-2-b8e63a1e0a31> in bootstrap_interval(X, y, group, clf, num_resample, p_value)
#      41
#      42         # Classify and get the results
# ---> 43         accuracies = classify_loso(sample_X, sample_y, sample_group, clf)
#      44         acc_distribution.append(np.mean(accuracies))
#      45
#
# ~/Documents/BIAPT/eeg-pain-detection/projects/publish_a_paper_on_pain_detection_using_eeg_and_ml/neurips_2020_abstract_submission/ml_tools/classification.py in classify_loso(X, y, group, clf)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(); 
ax = sns.distplot(acc_distribution, hist=False)
ax.set_title('Bootstrap Resampling Distribution of Accuracies')
plt.show()

# %%
ax = sns.boxplot(acc_distribution)
ax.set_title("Box plot of Bootstrap Resample Accuracies")
plt.show()
# Note: The wisker are at 1.5*IQR
# Out:
# (0.5199908517446482, 0.6162354201957848)

# %%
ax = sns.violinplot(acc_distribution)
ax.set_title("Violin plot of Bootstrap Resample Accuracies")

# %% [markdown]
# The distribution is able to be generated, I prefer the violin plot and the boxplot to showcase the performance of the classifier as it will allow direct comparison against different classifier. This is much better than a barplot with confidence interval.
